# %% [markdown]
# # Project: Web Scraping from an E-Book Store

# %%
# importing all the useful libraries
from bs4 import BeautifulSoup       # for web scraping
import requests                     # for making HTTP requests
import pandas as pd                 # for creating & managing dataframe

# %%
Book_Title = []                     # for storing Book Titles
Price = []                          # for storing Book Prices
Stock_Availibility = []             # for storing whether book is available or not
Product_Link = []

# %%
domain = 'https://books.toscrape.com'     # Domain of the website 'Books to scrape'

# %%
for pg in range(1,51):     
    url = 'https://books.toscrape.com/catalogue/page-'+str(pg)+'.html' 
    #print(url)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    #print(soup)

    h3 = soup.find_all('h3')        # for finding titles of all the books
    #print(h3)

    for i in h3:
        book = i.find('a')
        Book_Title.append(book.text)
        link = book.get('href')     # for finding url of product
        #print(link)
        link = domain + '/catalogue' + '/' + link
        Product_Link.append(link)

    p_price = soup.find_all('p', class_ = 'price_color')        # for finding prices of all the books
    #print(p_price)

    for price in p_price:
        book_price = price.text
        book_price = book_price.replace('Â', '')
        Price.append(book_price)

    p_stock = soup.find_all('p', class_ = "instock availability")       # for finding stock availability of all the books
    
    for stock in p_stock:
        book_stock = stock.text.strip()
        Stock_Availibility.append(book_stock)

    print(f'Page {pg} data has been scrapped successfully!')
# Out:
# Page 1 data has been scrapped successfully!
# Page 2 data has been scrapped successfully!
# Page 3 data has been scrapped successfully!
# Page 4 data has been scrapped successfully!
# Page 5 data has been scrapped successfully!
# Page 6 data has been scrapped successfully!
# Page 7 data has been scrapped successfully!
# Page 8 data has been scrapped successfully!
# Page 9 data has been scrapped successfully!
# Page 10 data has been scrapped successfully!
# Page 11 data has been scrapped successfully!
# Page 12 data has been scrapped successfully!
# Page 13 data has been scrapped successfully!
# Page 14 data has been scrapped successfully!
# Page 15 data has been scrapped successfully!
# Page 16 data has been scrapped successfully!
# Page 17 data has been scrapped successfully!
# Page 18 data has been scrapped successfully!
# Page 19 data has been scrapped successfully!
# Page 20 data has been scrapped successfully!
# Page 21 data has been scrapped successfully!
# ...

# %%
Book_Title
# Out:
# ['A Light in the ...',
#  'Tipping the Velvet',
#  'Soumission',
#  'Sharp Objects',
#  'Sapiens: A Brief History ...',
#  'The Requiem Red',
#  'The Dirty Little Secrets ...',
#  'The Coming Woman: A ...',
#  'The Boys in the ...',
#  'The Black Maria',
#  'Starving Hearts (Triangular Trade ...',
#  "Shakespeare's Sonnets",
#  'Set Me Free',
#  "Scott Pilgrim's Precious Little ...",
#  'Rip it Up and ...',
#  'Our Band Could Be ...',
#  'Olio',
#  'Mesaerion: The Best Science ...',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas",
#  'In Her Wake',
#  'How Music Works',
#  'Foolproof Preserving: A Guide ...',
#  'Chase Me (Paris Nights ...',
#  'Black Dust',
#  'Birdsong: A Story in ...',
#  "America's Cradle of Quarterbacks: ...",
#  'Aladdin and His Wonderful ...',
#  'Worlds Elsewhere: Journeys Around ...',
#  'Wall and Piece',
#  'The Four Agreements: A ...',
#  'The Five Love Languages: ...',
#  'The Elephant Tree',
#  'The Bear and the ...',
# ...

# %%
len(Book_Title)
# Out:
# 1000

# %%
Price
# Out:
# ['£51.77',
#  '£53.74',
#  '£50.10',
#  '£47.82',
#  '£54.23',
#  '£22.65',
#  '£33.34',
#  '£17.93',
#  '£22.60',
#  '£52.15',
#  '£13.99',
#  '£20.66',
#  '£17.46',
#  '£52.29',
#  '£35.02',
#  '£57.25',
#  '£23.88',
#  '£37.59',
#  '£51.33',
#  '£45.17',
#  '£12.84',
#  '£37.32',
#  '£30.52',
#  '£25.27',
#  '£34.53',
#  '£54.64',
#  '£22.50',
#  '£53.13',
#  '£40.30',
#  '£44.18',
#  '£17.66',
#  '£31.05',
#  '£23.82',
#  '£36.89',
#  '£15.94',
#  '£33.29',
#  '£18.02',
#  '£19.63',
#  '£52.22',
#  '£33.63',
#  '£57.31',
#  '£26.41',
#  '£47.61',
#  '£23.11',
#  '£45.07',
#  '£31.77',
#  '£50.27',
#  '£14.27',
#  '£44.18',
#  '£18.78',
#  '£25.52',
#  '£16.28',
#  '£31.12',
#  '£19.49',
#  '£17.27',
#  '£19.09',
#  '£56.13',
#  '£56.41',
#  '£56.50',
#  '£45.22',
#  '£38.16',
#  '£54.11',
#  '£42.96',
#  '£23.89',
#  '£16.77',
#  '£20.59',
#  '£37.13',
#  '£56.06',
#  '£58.11',
#  '£49.05',
#  '£40.76',
#  '£19.73',
#  '£32.24',
#  '£41.83',
#  '£39.58',
#  '£39.25',
# ...

# %%
len(Price)
# Out:
# 1000

# %%
Stock_Availibility
# Out:
# ['In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
# ...

# %%
len(Stock_Availibility)
# Out:
# 1000

# %%
Product_Link
# Out:
# ['https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#  'https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html',
#  'https://books.toscrape.com/catalogue/soumission_998/index.html',
#  'https://books.toscrape.com/catalogue/sharp-objects_997/index.html',
#  'https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html',
#  'https://books.toscrape.com/catalogue/the-requiem-red_995/index.html',
#  'https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#  'https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#  'https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#  'https://books.toscrape.com/catalogue/the-black-maria_991/index.html',
# ...

# %%
len(Product_Link)
# Out:
# 1000

# %%
# Storing all the scrapped data into a dataframe
df = pd.DataFrame({'Book_Title': Book_Title, 'Price': Price, 'Stock_Availibility': Stock_Availibility, 'Product_Link': Product_Link})

# %%
df.head()
# Out:
#                      Book_Title   Price Stock_Availibility  \
# 0            A Light in the ...  £51.77           In stock
# 1            Tipping the Velvet  £53.74           In stock
# 2                    Soumission  £50.10           In stock
# 3                 Sharp Objects  £47.82           In stock
# 4  Sapiens: A Brief History ...  £54.23           In stock
#
#                                         Product_Link
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...

# %%
df.sample(10)
# Out:
#                                   Book_Title   Price Stock_Availibility  \
# 309                                 El Deafo  £57.62           In stock
# 755  The Elegant Universe: Superstrings, ...  £13.03           In stock
# 660             Shopaholic Ties the Knot ...  £48.39           In stock
# 45                          When We Collided  £31.77           In stock
# 444                  23 Degrees South: A ...  £35.79           In stock
# 44           Without Borders (Wanderlove #1)  £45.07           In stock
# 161                  The Artist's Way: A ...  £38.49           In stock
# 502                         The Great Gatsby  £36.05           In stock
# 963                          Of Mice and Men  £47.11           In stock
# 476                          I Will Find You  £44.21           In stock
#
#                                           Product_Link
# 309  https://books.toscrape.com/catalogue/el-deafo_...
# 755  https://books.toscrape.com/catalogue/the-elega...
# ...

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Book_Title          1000 non-null   object
#  1   Price               1000 non-null   object
#  2   Stock_Availibility  1000 non-null   object
#  3   Product_Link        1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
df.to_csv('scrapped_data.csv', index=False)

# %%
df
# Out:
#                            Book_Title   Price Stock_Availibility  \
# 0                  A Light in the ...  £51.77           In stock
# 1                  Tipping the Velvet  £53.74           In stock
# 2                          Soumission  £50.10           In stock
# 3                       Sharp Objects  £47.82           In stock
# 4        Sapiens: A Brief History ...  £54.23           In stock
# ..                                ...     ...                ...
# 995  Alice in Wonderland (Alice's ...  £55.53           In stock
# 996    Ajin: Demi-Human, Volume 1 ...  £57.06           In stock
# 997         A Spy's Devotion (The ...  £16.97           In stock
# 998           1st to Die (Women's ...  £53.98           In stock
# 999           1,000 Places to See ...  £26.08           In stock
#
#                                           Product_Link
# 0    https://books.toscrape.com/catalogue/a-light-i...
# 1    https://books.toscrape.com/catalogue/tipping-t...
# ...
